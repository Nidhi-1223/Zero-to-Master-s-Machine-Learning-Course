# %% [markdown]
# ## Matplotlib Library
#
# - Matplotlib Importing
# - Two differnt ways to plot data
#     - Plotting data from Numpy Arrays
#     - Plotting data from pandas Dataframe
# - Customizing plots
# - Saving & sharing plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); #semicolon to get rid of that annoying bracket on the top

# %%
plt.plot()
plt.show()  #gonna do the exact same thing without the bracket

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
#fig method - method 1
fig = plt.figure()      #cretes a figure
ax =fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)    #adding some data
plt.show()

# %%
#method 3 (recommended)
fig, ax = plt.subplots()
z = [11,22,34,56]
ax.plot(x,z);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot-with-code.png)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. prepare data
x = [2,4,6,8]
y = [12,79,42,92]

#2. setup plot
fig,ax = plt.subplots(figsize=(7,7))    #(width,height)

#3. plot data
ax.plot(x,y)

#4. customize plot
ax.set(title="Simple Plot",
        xlabel = "x-axis",
        ylabel = "y-axis")

#5. save and show figure
fig.savefig("Assests/sample-plot-1.png")

# %% [markdown]
# ## Making figures with Numpy Arrays
# we want :
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
#import numpy

#create some data
x = np.linspace(0,10,num=100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
#plot the data and create a line plot
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(x, x**2);

# %%
#use same data to make scatter plots
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#creating a plot directly from dictonary
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Bar plot", xlabel="butter", ylabel="prices")
# Out:
# [Text(0.5, 1.0, 'Bar plot'), Text(0.5, 0, 'butter'), Text(0, 0.5, 'prices')]

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  9.,  30.,  83., 204., 247., 232., 124.,  52.,  15.,   4.]),
#  array([-3.06841454, -2.4174664 , -1.76651825, -1.11557011, -0.46462196,
#          0.18632618,  0.83727433,  1.48822247,  2.13917062,  2.79011876,
#          3.44106691]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Two options for subplots

# %%
#Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#plot to each different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(100))
# Out:
# (array([ 5.,  2.,  7., 12., 13., 19., 17., 11., 10.,  4.]),
#  array([-2.2741724 , -1.87714564, -1.48011888, -1.08309212, -0.68606536,
#         -0.2890386 ,  0.10798816,  0.50501492,  0.90204168,  1.29906845,
#          1.69609521]),
#  <BarContainer object of 10 artists>)

# %%
#option 2 for subplots
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))         #row - 0, column - 1
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  1.,   8.,  31., 106., 189., 251., 218., 124.,  51.,  21.]),
#  array([-3.52366667, -2.89562439, -2.26758211, -1.63953983, -1.01149755,
#         -0.38345527,  0.24458701,  0.87262929,  1.50067157,  2.12871385,
#          2.75675613]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Plotting from Pandas Dataframe

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("../Pandas Library/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
# /tmp/ipykernel_3763/4215731511.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Removing the extra zeros in the Price column
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
#Reassign our price column to be integer
car_sales["Price"] = car_sales["Price"].astype(int)
type(car_sales["Price"][0])
# Out:
# numpy.int64

# %%
#adding an extra column called "Sale Dates" to the DataFrame
car_sales["Sale Date"] = pd.date_range("1/1/2022", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
#Lets plot the total sales - Method 1
car_sales.plot(x="Sale Date", y = "Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# #### Method 2

# %%
#Bar graph using some dummy data
x = np.random.rand(10,4)
x
# Out:
# array([[0.97091118, 0.70891946, 0.6475901 , 0.60866609],
#        [0.8946735 , 0.05382588, 0.27302379, 0.50563497],
#        [0.56809596, 0.45720779, 0.98872076, 0.64122793],
#        [0.67852541, 0.70739566, 0.37732722, 0.69517442],
#        [0.54281135, 0.51619497, 0.67539707, 0.14119548],
#        [0.00817817, 0.28654602, 0.33742636, 0.25621477],
#        [0.07495792, 0.3394627 , 0.94182193, 0.88798272],
#        [0.41357516, 0.22072009, 0.53104882, 0.23988351],
#        [0.54500025, 0.29056526, 0.81987693, 0.27579031],
#        [0.48572385, 0.0038857 , 0.00753077, 0.01359067]])

# %%
#Turn it into a DataFrame
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.970911  0.708919  0.647590  0.608666
# 1  0.894674  0.053826  0.273024  0.505635
# 2  0.568096  0.457208  0.988721  0.641228
# 3  0.678525  0.707396  0.377327  0.695174
# 4  0.542811  0.516195  0.675397  0.141195
# 5  0.008178  0.286546  0.337426  0.256215
# 6  0.074958  0.339463  0.941822  0.887983
# 7  0.413575  0.220720  0.531049  0.239884
# 8  0.545000  0.290565  0.819877  0.275790
# 9  0.485724  0.003886  0.007531  0.013591

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#this line of code also does the same thing
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Using the same methods to manipulate our car_sales dataframe
car_sales.plot(x="Make", y="Odometer (KM)", kind= "bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
#Plotting Histograms
car_sales["Odometer (KM)"].plot.hist(bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist", bins= 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Trying out similar techniques on another Dataset

# %%
heart_disease = pd.read_csv("Assests/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Create a histogram of the age
heart_disease["age"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize= (10,30),subplots = True);
