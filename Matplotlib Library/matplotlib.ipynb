# %% [markdown]
# ## Matplotlib Library
#
# - Matplotlib Importing
# - Two differnt ways to plot data
#     - Plotting data from Numpy Arrays
#     - Plotting data from pandas Dataframe
# - Customizing plots
# - Saving & sharing plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); #semicolon to get rid of that annoying bracket on the top

# %%
plt.plot()
plt.show()  #gonna do the exact same thing without the bracket

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
#fig method - method 1
fig = plt.figure()      #cretes a figure
ax =fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)    #adding some data
plt.show()

# %%
#method 3 (recommended)
fig, ax = plt.subplots()
z = [11,22,34,56]
ax.plot(x,z);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot-with-code.png)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. prepare data
x = [2,4,6,8]
y = [12,79,42,92]

#2. setup plot
fig,ax = plt.subplots(figsize=(7,7))    #(width,height)

#3. plot data
ax.plot(x,y)

#4. customize plot
ax.set(title="Simple Plot",
        xlabel = "x-axis",
        ylabel = "y-axis")

#5. save and show figure
fig.savefig("Assests/sample-plot-1.png")

# %% [markdown]
# ## Making figures with Numpy Arrays
# we want :
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
#import numpy

#create some data
x = np.linspace(0,10,num=100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
#plot the data and create a line plot
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(x, x**2);

# %%
#use same data to make scatter plots
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#creating a plot directly from dictonary
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Bar plot", xlabel="butter", ylabel="prices")
# Out:
# [Text(0.5, 1.0, 'Bar plot'), Text(0.5, 0, 'butter'), Text(0, 0.5, 'prices')]

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  8.,  30.,  98., 167., 218., 222., 174.,  63.,  17.,   3.]),
#  array([-3.03697573, -2.40801157, -1.77904742, -1.15008326, -0.5211191 ,
#          0.10784506,  0.73680921,  1.36577337,  1.99473753,  2.62370168,
#          3.25266584]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Two options for subplots

# %%
#Subplot option 1
fig, ((ax1,ax2),(ax3,ax4),(a3,a4)) = plt.subplots(nrows=3,ncols=2,figsize=(15,10))
# plot to each different axis
ax1.plot(x,x**2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(100))
# Out:
# (array([ 1.,  0.,  3.,  7., 16., 12., 23., 19., 14.,  5.]),
#  array([-3.67906475, -3.07930774, -2.47955074, -1.87979373, -1.28003673,
#         -0.68027972, -0.08052272,  0.51923429,  1.11899129,  1.71874829,
#          2.3185053 ]),
#  <BarContainer object of 10 artists>)

# %%
# x = np.linspace(0,10,num=100)
# fig,ax = plt.subplots()
# ax.plot(x,x**2)

# %%
#option 2 for subplots
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))         #row - 0, column - 1
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  5.,  11.,  59., 140., 225., 264., 187.,  71.,  31.,   7.]),
#  array([-3.38705433, -2.74155256, -2.09605079, -1.45054901, -0.80504724,
#         -0.15954547,  0.48595631,  1.13145808,  1.77695985,  2.42246163,
#          3.0679634 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Plotting from Pandas Dataframe

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("../Pandas Library/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
# /tmp/ipykernel_9073/4215731511.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Removing the extra zeros in the Price column
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
#Reassign our price column to be integer
car_sales["Price"] = car_sales["Price"].astype(int)
type(car_sales["Price"][0])
# Out:
# numpy.int64

# %%
#adding an extra column called "Sale Dates" to the DataFrame
car_sales["Sale Date"] = pd.date_range("1/1/2022", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
#Lets plot the total sales - Method 1
car_sales.plot(x="Sale Date", y = "Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# #### Method 2

# %%
#Bar graph using some dummy data
x = np.random.rand(10,4)
x
# Out:
# array([[0.77284175, 0.27472132, 0.10642191, 0.5785211 ],
#        [0.54993347, 0.04220733, 0.53194124, 0.52264967],
#        [0.2219647 , 0.55289016, 0.91763745, 0.41392695],
#        [0.69270421, 0.61290988, 0.45427893, 0.33509293],
#        [0.51869199, 0.04964567, 0.92164054, 0.66801058],
#        [0.83808651, 0.85099342, 0.15357301, 0.41921106],
#        [0.49208214, 0.39942246, 0.24412314, 0.25365035],
#        [0.57458065, 0.35966588, 0.51740469, 0.24990281],
#        [0.26057941, 0.30349699, 0.5856306 , 0.22885519],
#        [0.47007789, 0.10441091, 0.9137654 , 0.92377789]])

# %%
#Turn it into a DataFrame
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.772842  0.274721  0.106422  0.578521
# 1  0.549933  0.042207  0.531941  0.522650
# 2  0.221965  0.552890  0.917637  0.413927
# 3  0.692704  0.612910  0.454279  0.335093
# 4  0.518692  0.049646  0.921641  0.668011
# 5  0.838087  0.850993  0.153573  0.419211
# 6  0.492082  0.399422  0.244123  0.253650
# 7  0.574581  0.359666  0.517405  0.249903
# 8  0.260579  0.303497  0.585631  0.228855
# 9  0.470078  0.104411  0.913765  0.923778

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#this line of code also does the same thing
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Using the same methods to manipulate our car_sales dataframe
car_sales.plot(x="Make", y="Odometer (KM)", kind= "bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
#Plotting Histograms
car_sales["Odometer (KM)"].plot.hist(bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist", bins= 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Trying out similar techniques on another Dataset

# %%
heart_disease = pd.read_csv("Assests/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Create a histogram of the age
heart_disease["age"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize= (10,30),subplots = True);

# %% [markdown]
# ### Which one should you use? (pyplot v/s the matplotlib OO method)
# - When plotting something quickly, it's okay to use the pyplot method
# - When plotting something advanced, use the OO method

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.head()

# %%
over_50.plot(kind="scatter",x = "age", y= "chol",c= "target")       #this is the basic pyplot method

# %%
#OO method mixed with pyplot figure
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x= 'age', y= 'chol', c= 'target',ax=ax)
# ax.set_xlim([45,100])

# %%
#OO method from sratch
fig,ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], c=over_50['target'])

#customize the plot
ax.set(title="Heart Disease & Cholestrol Levels",xlabel='Age', ylabel='Cholestrol')

#Add a legend
ax.legend(*scatter.legend_elements(), title='Target')

#Add a horizontal line
ax.axhline(y=over_50['chol'].mean(), linestyle='--')

# %%
#Subplot with max heart rate (thalach column in the over)
fig, (ax0,ax1) = plt.subplots(nrows=2,ncols=1, figsize= (10,10), sharex=True)
#add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"], c=over_50["target"])
#customize ax0
ax0.set(title='Heart Disease & Cholestrol levels', ylabel='Cholestrol')
#legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target')
#Add a mean line
ax0.axhline(y=over_50['chol'].mean(), linestyle= '--')


#add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"], c=over_50["target"])
#customize ax0
ax1.set(title='Heart Disease & Maximum Heart Rate', xlabel='Age', ylabel='Maximum Heart Rate')
#legend to ax0
ax1.legend(*scatter.legend_elements(), title='Target')
#Add a mean line
ax1.axhline(y=over_50['thalach'].mean(), linestyle= '--')

# #add a title to the figure
fig.suptitle("Heart Diseases Analysis", fontsize= 16, fontweight= 'bold')
# Out:
# Text(0.5, 0.98, 'Heart Diseases Analysis')

# %% [markdown]
# ### learning to customize the plots a little better

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#default style
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-whitegrid')
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.available

# %%
# plt.style.use('seaborn')
plt.style.use('seaborn-notebook') #- this is nice
# # plt.style.use('seaborn-colorblind')
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
#Creating some dummy data
x = np.random.randn(10,4)
x

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df

# %%
df.plot(kind='bar')

# %%
#customize this plot with the set() method
ax= df.plot(kind= 'bar')
ax.set(title='Random Numbers Bar Graph', xlabel='rows', ylabel='random numbers')
# ax.legend().set_visible(True)

# %%
#################### customizing that subplot####################################
'''
new attributes added - 
cmap
set_xlim, set_ylim

'''

#Subplot with max heart rate (thalach column in the over)
fig, (ax0,ax1) = plt.subplots(nrows=2,ncols=1, figsize= (10,10), sharex=True)
#add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"], c=over_50["target"],cmap='winter')
#customize ax0
ax0.set(title='Heart Disease & Cholestrol levels', ylabel='Cholestrol')
ax0.set_xlim([50,80])
#legend to ax0
ax0.legend(*scatter.legend_elements(), title='Target')
#Add a mean line
ax0.axhline(y=over_50['chol'].mean(), linestyle= '--')


#add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"], c=over_50["target"],cmap='winter')
#customize ax0
ax1.set(title='Heart Disease & Maximum Heart Rate', xlabel='Age', ylabel='Maximum Heart Rate')
ax1.set_ylim([60,200])
#legend to ax0
ax1.legend(*scatter.legend_elements(), title='Target')
#Add a mean line
ax1.axhline(y=over_50['thalach'].mean(), linestyle= '--')

#add a title to the figure
fig.suptitle("Heart Diseases Analysis", fontsize= 16, fontweight= 'bold')
# Out:
# Text(0.5, 0.98, 'Heart Diseases Analysis')

# %%
fig.savefig("Assests/Heart-Disease-Analysis-saved-with-code.png")
